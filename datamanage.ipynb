# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


#Load the data
df = pd.read_excel('/Twitter_fb_combined_final.xlsx')


#View the data

# %%
df.info()

#Describe the data

df.describe()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 37 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               195 non-null    int64
#  1   Company                          195 non-null    object
#  2   Year                             195 non-null    int64
#  3   NUM_OF_EMPLOYEES                 195 non-null    int64
#  4   NET_ASSETS                       195 non-null    float64
#  5   NET_INCOME                       195 non-null    float64
#  6   SALES_REV_TURN                   195 non-null    float64
#  7   HISTORICAL_MARKET_CAP            195 non-null    float64
#  8   ESG_DISCLOSURE_SCORE             195 non-null    float64
#  9   GOVNCE_DISCLOSURE_SCORE          195 non-null    float64
#  10  ENVIRON_DISCLOSURE_SCORE         195 non-null    float64
#  11  SOCIAL_DISCLOSURE_SCORE          195 non-null    float64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# ID                                 0
# Company                            0
# Year                               0
# NUM_OF_EMPLOYEES                   0
# NET_ASSETS                         0
# NET_INCOME                         0
# SALES_REV_TURN                     0
# HISTORICAL_MARKET_CAP              0
# ESG_DISCLOSURE_SCORE               0
# GOVNCE_DISCLOSURE_SCORE            0
# ENVIRON_DISCLOSURE_SCORE           0
# SOCIAL_DISCLOSURE_SCORE            0
# TOT_GHG_CO2_EM_INTENS_PER_SALES    0
# PCT_WOMEN_EMPLOYEES                0
# PCT_WOMEN_ON_BOARD                 0
# ROBECOSAM_TOTAL_STBLY_RANK         0
# ROBECOSAM_SOCIAL_DIMENSION_RANK    0
# ROBECOSAM_ENV_DIMENSION_RANK       0
# ROBECOSAM_ECON_DIMENSION_RANK      0
# Twitter_Userme                     0
# followers_count                    0
# friends_count                      0
# created_at                         0
# Tweets                             0
# Likes                              0
# ...

# %%
df.corr()
# Out:
#                                            ID          Year  NUM_OF_EMPLOYEES  \
# ID                               1.000000e+00 -3.268554e-13         -0.208793
# Year                            -3.268554e-13  1.000000e+00          0.005788
# NUM_OF_EMPLOYEES                -2.087926e-01  5.787708e-03          1.000000
# NET_ASSETS                      -1.880598e-01 -4.168273e-04          0.330773
# NET_INCOME                      -8.980936e-02  1.127764e-01          0.420546
# SALES_REV_TURN                  -1.489303e-01  5.222086e-02          0.702633
# HISTORICAL_MARKET_CAP           -3.002188e-02  4.997579e-03          0.423325
# ESG_DISCLOSURE_SCORE            -5.846538e-02  8.588287e-02         -0.079102
# GOVNCE_DISCLOSURE_SCORE         -1.367367e-01  9.020696e-02         -0.013165
# ENVIRON_DISCLOSURE_SCORE         2.097020e-03  3.697908e-02         -0.110503
# SOCIAL_DISCLOSURE_SCORE         -1.096305e-01  1.213843e-01         -0.031170
# ...

# %%
corr = df.corr()
kot = corr[corr>=.50]
plt.figure(figsize=(12,8))
sns.heatmap(kot, cmap="Reds")

# %%
df.corr().to_excel("newrelationab.xlsx")
